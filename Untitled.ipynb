# %% [markdown]
# <a href="https://colab.research.google.com/github/silviogab/API/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from neuprint import Client, fetch_neurons, fetch_adjacencies, NeuronCriteria as NC

# ---------------------------------------------------------------------
TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..6ILS2049MGvV83ZaPHUYtj-PTg9RwYC8HVwzw4dSRUs"
DATASET = "hemibrain:v1.2.1"
SERVER = "https://neuprint.janelia.org"
# ---------------------------------------------------------------------

client = Client(SERVER, dataset=DATASET, token=TOKEN)

tipos_alvo = ["ORN.*", "PN.*", "KC.*", "EPG", "PEG"]

print("Buscando neurônios...")
criteria = NC(type=tipos_alvo, regex=True)
neurons_df, roi_counts_df = fetch_neurons(criteria)
print(f"  {len(neurons_df)} neurônios encontrados.")

print("Buscando sinapses entre eles...")
neuron_ids = neurons_df["bodyId"].tolist()
conn_criteria = NC(bodyId=neuron_ids)
neurons_conn_df, conn_df = fetch_adjacencies(conn_criteria, conn_criteria)
print(f"  {len(conn_df)} conexões encontradas.")

nodes = [
    {"id": int(row.bodyId), "type": str(row.type)}
    for row in neurons_df.itertuples()
]

edges = [
    {
        "pre": int(row.bodyId_pre),
        "post": int(row.bodyId_post),
        "weight": int(row.weight)
    }
    for row in conn_df.itertuples()
]

circuito = {
    "dataset": DATASET,
    "descricao": "Circuito olfativo -> corpo em cogumelo -> complexo central",
    "n_neuronios": len(nodes),
    "n_conexoes": len(edges),
    "nodes": nodes,
    "edges": edges,
}

with open("circuito_mosca.json", "w", encoding="utf-8") as f:
    json.dump(circuito, f, ensure_ascii=False, indent=2)

print(f"\nPronto: circuito_mosca.json ({len(nodes)} neurônios, {len(edges)} conexões)")
# Out:
# Buscando neurônios...
#   4568 neurônios encontrados.
# Buscando sinapses entre eles...
#   0%|          | 0/23 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   465612 conexões encontradas.
#
# Pronto: circuito_mosca.json (4568 neurônios, 465612 conexões)

# %%
# !pip install neuprint-python pandas
